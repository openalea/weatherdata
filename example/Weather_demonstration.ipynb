# %% [markdown]
# ## 1. Acces to IPM Source from OpenAlea python
# Access to notebook https://github.com/openalea/weatherdata/blob/master/example/Weather_demonstration.ipynb

# %%
import logging, sys
from openalea.weatherdata import WeatherDataHub
from openalea.weatherdata.getdata import datadir

# %% [markdown]
# ## 1.1 Access to IPM Catalog and IPM list of weather parameters

# %%
ws= WeatherDataHub()
ws.list_resources
# Out:
#                                                     name  \
# no.met.locationforecast      Met Norway Locationforecast
# ie.gov.data                 Met Éireann Locationforecast
# dk.dmi.pointweather             DMI Pointweather service
# se.slu.lantmet                       SLU Lantmet service
# com.open-meteo                                Open-Meteo
# ...                                                  ...
# no.nibio.lmt             Landbruksmeteorologisk tjeneste
# com.meteobot                                MeteoBot API
# info.fruitweb                                   Fruitweb
# net.ipmdecisions.metos                             Metos
# fr.meteo-concept.api          Meteodata by Météo Concept
#
#                                                                                                                                                                                                                                   description  \
# no.met.locationforecast                                                                                                                   9-day forecasts for the entire planet. 2.5 km resolution in the Nordic-Baltic region, 9km elsewhere
# ie.gov.data                                                                                                                                                                                                      9-day forecasts for Ireland.
# dk.dmi.pointweather                                                                                                                                                               Seasonal weather data and forecasts for Denmark. Grid based
# se.slu.lantmet                                                                                                                                                                     Seasonal weather data and forecasts for Sweden. Grid based
# com.open-meteo                                                                                                                                                                       Seasonal weather data and forecasts for the entire world
# ...                                                                                                                                                                                                                                       ...
# no.nibio.lmt                                                                                               Weather station network covering major agricultural areas of Norway. Data before 2010 are available by request. Email lmt@nibio.no
# com.meteobot                                                                                                                        Network of privately owned weather stations. Access requires permission from each weather station's owner
# info.fruitweb                                                                  Network of privately owned weather stations of several types; Davis, Metos and self manufactured. Access requires permission from each weather station's owner
# net.ipmdecisions.metos                                                         Network of privately owned weather stations of several types; Davis, Metos and self manufactured. Access requires permission from each weather station's owner
# fr.meteo-concept.api     Weather station network covering all of mainland France, with a specially high density of agricultural stations in Brittany. Visit www.meteodata.fr and www.meteo-concept.fr or email us at contact@meteo-concept.fr
#
#                                                                                                                              parameters
# no.met.locationforecast                                                          {'common': [1001, 3001, 2001, 4002], 'optional': None}
# ie.gov.data                                                                      {'common': [1001, 3001, 2001, 4002], 'optional': None}
# dk.dmi.pointweather                                                  {'common': [1002, 1112, 2001, 3002, 3101, 4002], 'optional': None}
# se.slu.lantmet                                     {'common': [1002, 1003, 1004, 2001, 3002, 3003, 3004, 4003, 5001], 'optional': None}
# com.open-meteo                                           {'common': [1001, 1003, 1004, 1901, 2001, 3001, 4012, 5001], 'optional': None}
# ...                                                                                                                                 ...
# no.nibio.lmt                                                 {'common': [1002, 1003, 1004, 3002, 2001, 4003], 'optional': [3101, 5001]}
# com.meteobot                                                         {'common': [1001, 1002, 3001, 3002, 2001, 4002], 'optional': None}
# info.fruitweb                                                        {'common': [1001, 1002, 3001, 3002, 2001, 4002], 'optional': None}
# net.ipmdecisions.metos                                               {'common': [1001, 1002, 3001, 3002, 2001, 4002], 'optional': None}
# fr.meteo-concept.api     {'common': [1001, 2001, 3001, 4001, 4003], 'optional': [1003, 1004, 1021, 1101, 1131, 3003, 3004, 3101, 5001]}
#
# [15 rows x 3 columns]

# %%
ws.parameters
# Out:
#       id                                 name description     unit  \
# 0   1001      Instantaneous temperature at 2m        None  Celcius
# 1   1002           Mean air temperature at 2m        None  Celcius
# 2   1003        Minimum air temperature at 2m        None  Celcius
# 3   1004        Maximum air temperature at 2m        None  Celcius
# 4   1021  Instantaneous temperature in canopy        None  Celcius
# ..   ...                                  ...         ...      ...
# 39  4012      Instantaneous wind speed at 10m        None      m/s
# 40  4013               Mean wind speed at 10m        None      m/s
# 41  4014                Max wind speed at 10m        None      m/s
# 42  4015                Min wind speed at 10m        None      m/s
# 43  5001         Solar radiation (Q0) (W/sqm)        None    W/sqm
#
#    aggregationType
# 0              AVG
# 1              AVG
# 2              MIN
# 3              MAX
# 4              AVG
# ..             ...
# 39             AVG
# 40             AVG
# 41             MAX
# 42             MIN
# 43             SUM
#
# [44 rows x 5 columns]

# %% [markdown]
# ## 1.2 Get a ressource, access to meta-information of this ressource

# %% [markdown]
# ### 1.2.1 get ressouce

# %%
fmi = ws.get_ressource(name='fi.fmi.observation.station')

# %% [markdown]
# ### 1.2.2 Meta-informations of the ressource

# %% [markdown]
# ### 1.2.2.1  List of parameters

# %%
fmi.parameter
# Out:
#       id                        name description     unit aggregationType
# 1   1002  Mean air temperature at 2m        None  Celcius             AVG
# 21  2001               Precipitation        None       mm             SUM
# 23  3002               Mean RH at 2m        None        %             AVG
# 35  4003       Mean wind speed at 2m        None      m/s             AVG

# %% [markdown]
# ### 1.2.2.2 list of stations

# %%
fmi.stations
# Out:
#                                name latitude longitude
# 101533               Alajärvi Möksy    24.26     63.09
# 101185      Asikkala Pulkkilanharju    25.52     61.27
# 102017  Enontekiö Kilpisjärvi Saana    20.85     69.04
# 102016        Enontekiö Kilpisjärvi    20.79     69.05
# 102019            Enontekiö Näkkälä    23.58      68.6
# ...                             ...      ...       ...
# 101231         Virolahti Koivuniemi    27.67     60.53
# 101310             Virrat Äijänneva    23.54     62.33
# 101908        Ylitornio Meltosjärvi    24.65     66.53
# 101690           Ylivieska airfield    24.72     64.05
# 101520                  Ähtäri Inha    24.14     62.55
#
# [208 rows x 3 columns]

# %% [markdown]
# ### 1.2 Get data and visualized
# * get data according to weather parameters or several localisation

# %%
logging.disable(sys.maxsize)
exclude=[137188,101649,855522,137189,126737]
list_station=[int(id) for id in fmi.stations.index if not int(id) in exclude][0:120]

# %%
ds=fmi.data(parameters=[1002,3002],
            stationId=list_station,
            timeZone="Europe/Oslo",savecache=True,usecache=True)
ds
# Out:
# <xarray.Dataset> Size: 936kB
# Dimensions:   (time: 505, location: 115)
# Coordinates:
#   * time      (time) datetime64[us] 4kB 2020-06-11T22:00:00 ... 2020-07-02T22...
#   * location  (location) int64 920B 100907 100909 100917 ... 852678 874863
#     lat       (location) float64 920B 60.13 60.24 60.18 ... 59.5 60.29 60.18
#     lon       (location) float64 920B 19.9 24.05 19.99 ... 20.35 24.57 24.79
# Data variables:
#     1002      (time, location) float64 465kB 11.4 13.2 13.0 ... 17.0 13.9 15.0
#     3002      (time, location) float64 465kB 74.0 91.0 72.0 ... 63.0 99.0 96.0
# Attributes:
#     weatherRessource:  fi.fmi.observation.station
#     timeStart:         2020-06-11T22:00:00.000000
#     timeEnd:           2020-07-02T22:00:00.000000
#     parameters:        ['1002', '3002']

# %% [markdown]
# * Visualization

# %%
fmi.plot(ds,varname='1002',location=[100907,100909,852678,874863],resample=None)
# Out:
# [<matplotlib.lines.Line2D at 0x19018b620>,
#  <matplotlib.lines.Line2D at 0x18fe6d940>,
#  <matplotlib.lines.Line2D at 0x18fe6da90>,
#  <matplotlib.lines.Line2D at 0x18fe6dbe0>]

# %%
fmi.station_plot(ds=ds, varname="1002",time=0,resample=None)

# %% [markdown]
# ## 2. Add local OpenAlea ressouce to local IPM catalog

# %% [markdown]
# * import local data

# %%
data=ws.__data_reader__(datadir + '/Boigneville_2012_2013_h.csv')
data
# Out:
#                      temperature_air  relative_humidity  rain  wind_speed  \
# 2012-09-01 00:00:00              8.6               74.5   0.0    1.666667
# 2012-09-01 01:00:00              7.5               76.5   0.0    1.666667
# 2012-09-01 02:00:00              7.5               78.0   0.0    1.388889
# 2012-09-01 03:00:00              7.0               80.0   0.0    1.111111
# 2012-09-01 04:00:00              6.7               81.0   0.0    1.388889
# ...                              ...                ...   ...         ...
# 2013-08-31 19:00:00             18.3               74.5   0.0    0.833333
# 2013-08-31 20:00:00             17.8               78.5   0.0    1.666667
# 2013-08-31 21:00:00             17.9               78.0   0.0    2.222222
# 2013-08-31 22:00:00             17.0               77.0   0.0    2.777778
# 2013-08-31 23:00:00             15.9               75.0   0.0    3.611111
#
#                      global_radiation
# 2012-09-01 00:00:00               0.0
# 2012-09-01 01:00:00               0.0
# 2012-09-01 02:00:00               0.0
# 2012-09-01 03:00:00               0.0
# 2012-09-01 04:00:00               0.0
# ...                               ...
# 2013-08-31 19:00:00               0.0
# 2013-08-31 20:00:00               0.0
# 2013-08-31 21:00:00               0.0
# 2013-08-31 22:00:00               0.0
# 2013-08-31 23:00:00               0.0
#
# [8760 rows x 5 columns]

# %% [markdown]
# * Add the local_ressources

# %%
ws.add_local_ressource(name="Mydata",
                       data=data,
                       latitude=3.876716,
                       longitude=43.610769,
                       altitude=0,
                       convert_name={"temperature_air":1001,
                                     "relative_humidity":3001,
                                     "rain":2001,
                                     "wind_speed":4005,
                                     "global_radiation":5001})
# Out:
#                      1001  3001  2001      4005  5001
# 2012-09-01 00:00:00   8.6  74.5   0.0  1.666667   0.0
# 2012-09-01 01:00:00   7.5  76.5   0.0  1.666667   0.0
# 2012-09-01 02:00:00   7.5  78.0   0.0  1.388889   0.0
# 2012-09-01 03:00:00   7.0  80.0   0.0  1.111111   0.0
# 2012-09-01 04:00:00   6.7  81.0   0.0  1.388889   0.0
# ...                   ...   ...   ...       ...   ...
# 2013-08-31 19:00:00  18.3  74.5   0.0  0.833333   0.0
# 2013-08-31 20:00:00  17.8  78.5   0.0  1.666667   0.0
# 2013-08-31 21:00:00  17.9  78.0   0.0  2.222222   0.0
# 2013-08-31 22:00:00  17.0  77.0   0.0  2.777778   0.0
# 2013-08-31 23:00:00  15.9  75.0   0.0  3.611111   0.0
#
# [8760 rows x 5 columns]

# %% [markdown]
# The ressources has been added at the local catalog to be used like any other ressources of the catalog

# %%
ws.list_resources
# Out:
#                                                                                            name  \
# no.met.locationforecast                                             Met Norway Locationforecast
# ie.gov.data                                                        Met Éireann Locationforecast
# dk.dmi.pointweather                                                    DMI Pointweather service
# se.slu.lantmet                                                              SLU Lantmet service
# net.ipmdecisions.dwd.forecast.germany  Deutsche Wetterdienst location forecast by IPM Decisions
# ...                                                                                         ...
# com.meteobot                                                                       MeteoBot API
# info.fruitweb                                                                          Fruitweb
# net.ipmdecisions.metos                                                                    Metos
# fr.meteo-concept.api                                                 Meteodata by Météo Concept
# personal_data                                                                            Mydata
#
#                                                                                                                                                                                                                                                                                   description  \
# no.met.locationforecast                                                                                                                                                                   9-day forecasts for the entire planet. 2.5 km resolution in the Nordic-Baltic region, 9km elsewhere
# ie.gov.data                                                                                                                                                                                                                                                      9-day forecasts for Ireland.
# dk.dmi.pointweather                                                                                                                                                                                                               Seasonal weather data and forecasts for Denmark. Grid based
# se.slu.lantmet                                                                                                                                                                                                                     Seasonal weather data and forecasts for Sweden. Grid based
# net.ipmdecisions.dwd.forecast.germany  27 hour weather forecasts for Germany and surrounding areas. 2.5 km resolution. Pulls data from DWD's Open Data server (https://www.dwd.de/EN/ourservices/opendata/opendata.html). Made available by a custom adapter created by Met Norway and NIBIO.
# ...                                                                                                                                                                                                                                                                                       ...
# com.meteobot                                                                                                                                                                        Network of privately owned weather stations. Access requires permission from each weather station's owner
# info.fruitweb                                                                                                                  Network of privately owned weather stations of several types; Davis, Metos and self manufactured. Access requires permission from each weather station's owner
# net.ipmdecisions.metos                                                                                                         Network of privately owned weather stations of several types; Davis, Metos and self manufactured. Access requires permission from each weather station's owner
# fr.meteo-concept.api                                                     Weather station network covering all of mainland France, with a specially high density of agricultural stations in Brittany. Visit www.meteodata.fr and www.meteo-concept.fr or email us at contact@meteo-concept.fr
# personal_data                                                                                                                                                                                                                                                                   personal data
#
#                                                                                                                                            parameters
# no.met.locationforecast                                                                        {'common': [1001, 3001, 2001, 4002], 'optional': None}
# ie.gov.data                                                                                    {'common': [1001, 3001, 2001, 4002], 'optional': None}
# dk.dmi.pointweather                                                                {'common': [1002, 1112, 2001, 3002, 3101, 4002], 'optional': None}
# se.slu.lantmet                                                   {'common': [1002, 1003, 1004, 2001, 3002, 3003, 3004, 4003, 5001], 'optional': None}
# net.ipmdecisions.dwd.forecast.germany                                                          {'common': [1001, 3001, 2001, 4002], 'optional': None}
# ...                                                                                                                                               ...
# com.meteobot                                                                                   {'common': [1001, 3001, 2001, 4002], 'optional': None}
# info.fruitweb                                                                                  {'common': [1001, 3001, 2001, 4002], 'optional': None}
# net.ipmdecisions.metos                                                                         {'common': [1001, 3001, 2001, 4002], 'optional': None}
# fr.meteo-concept.api                   {'common': [1001, 2001, 3001, 4001, 4003], 'optional': [1003, 1004, 1021, 1101, 1131, 3003, 3004, 3101, 5001]}
# personal_data                                                                            {'common': [1001, 3001, 2001, 4005, 5001], 'optional': None}
#
# [16 rows x 3 columns]

# %%
personal_data=ws.get_ressource(name="personal_data")
ds=personal_data.to_ipm(display="ds")
ds
# Out:
#                      1001  3001  2001      4005  5001
# 2012-09-01 00:00:00   8.6  74.5   0.0  1.666667   0.0
# 2012-09-01 01:00:00   7.5  76.5   0.0  1.666667   0.0
# 2012-09-01 02:00:00   7.5  78.0   0.0  1.388889   0.0
# 2012-09-01 03:00:00   7.0  80.0   0.0  1.111111   0.0
# 2012-09-01 04:00:00   6.7  81.0   0.0  1.388889   0.0
# ...                   ...   ...   ...       ...   ...
# 2013-08-31 19:00:00  18.3  74.5   0.0  0.833333   0.0
# 2013-08-31 20:00:00  17.8  78.5   0.0  1.666667   0.0
# 2013-08-31 21:00:00  17.9  78.0   0.0  2.222222   0.0
# 2013-08-31 22:00:00  17.0  77.0   0.0  2.777778   0.0
# 2013-08-31 23:00:00  15.9  75.0   0.0  3.611111   0.0
#
# [8760 rows x 5 columns]

# %%
personal_data.plot(ds,varname="1001",resample="d")

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.dpi'] = 300        # display DPI
plt.rcParams['savefig.dpi'] = 300

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
fig = fmi.plot(ds,varname='1002',location=[100907,100909,852678,874863],resample=None)

# %%
import pandas
pandas.set_option('display.max_rows',10)
pandas.set_option('display.max_colwidth',None)
import matplotlib.pyplot as plt

plt.rcParams['figure.dpi'] = 300 #dpi
plt.rcParams['savefig.dpi'] = 300
